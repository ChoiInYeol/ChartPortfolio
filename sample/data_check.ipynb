# %%
import pandas as pd

df = pd.read_feather("../processed_data/us_stock_data_2024.feather")
df

df.columns
# Out:
# Index(['Date', 'StockID', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Vol',
#        'Ret', 'log_ret', 'cum_log_ret', 'EWMA_vol', 'Ret_week', 'Ret_month',
#        'Ret_quarter', 'Ret_year', 'Ret_5d', 'Ret_20d', 'Ret_60d', 'Ret_65d',
#        'Ret_180d', 'Ret_250d', 'Ret_260d'],
#       dtype='object')

# %%
import pickle

path = '../POD/data/dataset.pkl'
date = '../POD/data/date.pkl'

# path 데이터 읽기
with open(path, 'rb') as f:
    dataset = pickle.load(f)
    
with open(date, 'rb') as f:
    date = pickle.load(f)

dataset
# Out:
# [array([[[-7.10e-02, -3.70e-02, -2.00e+00, ..., -2.00e+00,  7.80e-02,
#           -2.00e+00],
#          [ 1.03e-01,  1.40e-02, -2.00e+00, ..., -2.00e+00, -3.20e-02,
#           -2.00e+00],
#          [ 3.80e-02,  3.30e-02, -2.00e+00, ..., -2.00e+00, -1.00e-02,
#           -2.00e+00],
#          ...,
#          [-2.00e-02,  1.10e-02, -2.00e+00, ..., -2.00e+00,  1.90e-02,
#           -2.00e+00],
#          [-4.00e-03,  5.30e-02, -2.00e+00, ..., -2.00e+00, -6.00e-03,
#           -2.00e+00],
#          [-1.15e-01, -2.10e-02, -2.00e+00, ..., -2.00e+00,  8.00e-03,
#           -2.00e+00]],
#
#         [[ 1.03e-01,  1.40e-02, -2.00e+00, ..., -2.00e+00, -3.20e-02,
#           -2.00e+00],
#          [ 3.80e-02,  3.30e-02, -2.00e+00, ..., -2.00e+00, -1.00e-02,
#           -2.00e+00],
#          [-5.50e-02, -1.90e-02, -2.00e+00, ..., -2.00e+00,  1.00e-02,
#           -2.00e+00],
#          ...,
#          [-4.00e-03,  5.30e-02, -2.00e+00, ..., -2.00e+00, -6.00e-03,
#           -2.00e+00],
# ...
