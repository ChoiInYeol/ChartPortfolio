# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use(['science','nature'])
import os

# us_ret.feather 불러오기
us_ret = pd.read_feather('./RIPT_processed_data/us_ret.feather')

# Train 이후 데이터만 사용
TRAIN = '2019-01-01'
us_ret = us_ret[us_ret['Date'] >= TRAIN]

# 종목별 수익률을 수익률 벡터로 변환
us_ret = us_ret.pivot(index='Date', columns='StockID', values='Ret')

# 수익률이 없는 날은 0으로 채움
us_ret.fillna(0, inplace=True)
us_ret.to_feather('./RIPT_processed_data/us_ret_TRAIN.feather')

# %%
import os
import pandas as pd

def load_ensemble_results(folder_path):
    """
    폴더 내의 모든 앙상블 결과 파일을 로드하고 하나의 데이터프레임으로 병합합니다.
    
    Args:
        folder_path (str): 앙상블 결과 파일이 있는 폴더 경로
    
    Returns:
        pd.DataFrame: 병합된 앙상블 결과 데이터프레임
    """
    all_data = []
    for file in os.listdir(folder_path):
        if file.endswith('.csv') and 'ensem' in file:
            file_path = os.path.join(folder_path, file)
            df = pd.read_csv(file_path)
            
            df['ending_date'] = pd.to_datetime(df['ending_date'])
            df['StockID'] = df['StockID'].astype(str)
            df.set_index(['ending_date', 'StockID'], inplace=True)
            
            all_data.append(df)
    
    if not all_data:
        raise ValueError(f"No CSV files found in {folder_path}")
    
    combined_df = pd.concat(all_data)
    combined_df.sort_index(inplace=True)
    
    # unnamed 컬럼 제거
    combined_df = combined_df.loc[:, ~combined_df.columns.str.contains('^Unnamed')]
    
    # MarketCap 컬럼 제거
    if 'MarketCap' in combined_df.columns:
        combined_df.drop('MarketCap', axis=1, inplace=True)
    
    return combined_df

def process_ensemble_results(base_folder):
    """
    모든 모델과 윈도우 사이즈에 대해 앙상블 결과를 처리합니다.
    
    Args:
        base_folder (str): 기본 폴더 경로
    """
    models = ['CNN', 'TS']
    window_sizes = [5, 20, 60]
    
    for model in models:
        for w in window_sizes:
            folder_path = os.path.join(base_folder, f'{model}{w}', f'{w}D20P', 'ensem_res')
            output_path = f'./RIPT_WORK_SPACE/ensemble_{model}{w}_res.feather'
            
            print(f'Processing Ensemble {model}{w}...   ', end='')
            try:
                ensemble_results = load_ensemble_results(folder_path)
                ensemble_results.to_feather(output_path)
                print(f'Shape of the dataframe: {ensemble_results.shape}')
            except Exception as e:
                print(f'Error processing {model}{w}: {str(e)}')

# 메인 실행 코드
if __name__ == "__main__":
    base_folder = 'RIPT_WORK_SPACE/new_model_res/'
    process_ensemble_results(base_folder)
# Out:
# Processing Ensemble CNN5...   Error processing CNN5: [Errno 2] No such file or directory: 'RIPT_WORK_SPACE/new_model_res/CNN5/5D20P/ensem_res'
# Processing Ensemble CNN20...   Shape of the dataframe: (620003, 2)
# Processing Ensemble CNN60...   Error processing CNN60: [Errno 2] No such file or directory: 'RIPT_WORK_SPACE/new_model_res/CNN60/60D20P/ensem_res'
# Processing Ensemble TS5...   Error processing TS5: [Errno 2] No such file or directory: 'RIPT_WORK_SPACE/new_model_res/TS5/5D20P/ensem_res'
# Processing Ensemble TS20...   Error processing TS20: [Errno 2] No such file or directory: 'RIPT_WORK_SPACE/new_model_res/TS20/20D20P/ensem_res'
# Processing Ensemble TS60...   Error processing TS60: [Errno 2] No such file or directory: 'RIPT_WORK_SPACE/new_model_res/TS60/60D20P/ensem_res'

# %%
import numpy as np
import pandas as pd
from scipy.optimize import minimize

# us_ret와 top_stocks가 이미 로드되어 있다고 가정합니다.

def select_top_stocks(top_stocks, rebalance_dates, n):
    """각 리밸런싱 날짜에 대해 상위 주식을 선택합니다."""
    selected_stocks = []
    for date in rebalance_dates:
        selected = top_stocks[top_stocks['ending_date'] == date].head(n)['StockID'].tolist()
        selected_stocks.append((date, selected))
    return selected_stocks

def portfolio_optimization(returns):
    """포트폴리오 최적화 함수"""
    n = returns.shape[1]
    cov_matrix = returns.cov()
    
    def portfolio_variance(weights):
        return np.dot(weights.T, np.dot(cov_matrix, weights))
    
    constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
    bounds = tuple((0, 1) for _ in range(n))
    initial_weights = np.array([1. / n] * n)
    
    result = minimize(portfolio_variance, initial_weights, method='SLSQP', bounds=bounds, constraints=constraints)
    
    if result.success:
        return result.x
    else:
        raise Exception('최적화 실패')

# 메인 실행 코드
TRAIN = '2019-01-01'
N_TOP_STOCKS = 50

# top_stocks를 TRAIN 날짜 이후의 데이터만 포함하도록 필터링
top_stocks = top_stocks[top_stocks['ending_date'] >= TRAIN]

# 고유한 리밸런싱 날짜 가져오기
rebalance_dates = top_stocks['ending_date'].unique()

# 각 리밸런싱 날짜에 대해 상위 N개 주식 선택
selected_stocks_list = select_top_stocks(top_stocks, rebalance_dates, N_TOP_STOCKS)

# 포트폴리오 가중치를 저장할 딕셔너리
portfolio_weights = {}

# 각 리밸런싱 기간에 대해 반복
for i, (rebalance_date, stock_ids) in enumerate(selected_stocks_list):
    # 룩어헤드 편향을 피하기 위해 리밸런싱 날짜까지의 데이터만 사용
    end_date = rebalance_date
    if i > 0:
        start_date = selected_stocks_list[i - 1][0]  # 이전 리밸런싱 날짜
    else:
        start_date = us_ret.index.min()  # 또는 정의된 시작 날짜

    # 최적화 기간에 대한 수익률 추출
    period_returns = us_ret.loc[start_date:end_date, stock_ids]

    # 결측 데이터 처리
    period_returns = period_returns.dropna(axis=1, how='all')

    if period_returns.shape[1] < 2:
        print(f"{end_date}에 끝나는 기간에 대해 최적화할 충분한 데이터가 없습니다")
        continue

    # 포트폴리오 최적화 수행
    try:
        weights = portfolio_optimization(period_returns)
        portfolio_weights[rebalance_date] = pd.Series(weights, index=period_returns.columns)
        print(f"{rebalance_date}에 시작하는 기간에 대해 포트폴리오 최적화 완료")
    except Exception as e:
        print(f"{rebalance_date}에 시작하는 기간에 대해 최적화 실패: {e}")

# 포트폴리오 가중치 표시
portfolio_weights_df = pd.DataFrame(portfolio_weights)
print(portfolio_weights_df)
# Out:
# 2019-01-31 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2019-02-28 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2019-04-30 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2019-05-31 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2019-07-31 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2019-09-30 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2019-10-31 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2019-12-31 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2020-01-31 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2020-03-31 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2020-04-30 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2020-06-30 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2020-07-31 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2020-08-31 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2020-09-30 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2020-11-30 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2020-12-31 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2021-03-31 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2021-04-30 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2021-06-30 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2021-08-31 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2021-09-30 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2021-11-30 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2021-12-31 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2022-01-31 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2022-02-28 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2022-03-31 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2022-05-31 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2022-06-30 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2022-08-31 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2022-09-30 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2022-10-31 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2022-11-30 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2023-01-31 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2023-02-28 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2023-03-31 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2023-05-31 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2023-06-30 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2023-07-31 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2023-08-31 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 2023-10-31 00:00:00에 시작하는 기간에 대해 포트폴리오 최적화 완료
# 1019     3.686287e-18    0.023291    0.020431    0.020519  2.286299e-02
# 102      3.791549e-02    0.024725    0.020616    0.020543  1.664409e-02
# 1020     1.159043e-02    0.016398    0.020130    0.020099  4.795471e-02
# 1021     6.234162e-19    0.018292    0.020310    0.020411  3.440648e-18
# 1024     2.877785e-02    0.024796    0.020504    0.020508  5.422060e-02
# 1025     2.589606e-02    0.020227    0.020410    0.020450  1.826434e-02
# 1026     0.000000e+00    0.022633    0.019771    0.020293  2.424108e-02
# 1027     2.513112e-02    0.022988    0.020382    0.020524  4.199977e-02
# 1028     4.328743e-02    0.022758    0.020426    0.020517  3.977017e-02
# 103      2.276832e-02    0.019426    0.020392    0.020326  1.456897e-19
# 1030     5.675149e-03    0.019792    0.020458    0.020454  2.815304e-02
# 1031     1.767270e-02    0.018909    0.020371    0.020370  0.000000e+00
# 1034     3.108284e-02    0.018117    0.020520    0.020442  1.196011e-18
# 1035     5.421011e-19    0.017596    0.020417    0.020380  3.902701e-03
# 1036     1.098136e-04    0.020924    0.020416    0.020381  3.190440e-02
# 1037     1.490778e-18    0.017798    0.020159    0.020306  0.000000e+00
# 1038     5.400743e-03    0.019197    0.020575    0.020472  2.870474e-02
# 1039     1.616878e-02    0.020372    0.020571    0.020445  3.322341e-02
# 104      9.618596e-04    0.000000    0.020271    0.020573  3.603077e-02
# 1040     3.008661e-18    0.021138    0.020376    0.020329  1.715784e-04
# 1041     4.618907e-02    0.021564    0.020537    0.020501  3.004089e-02
# 1042     6.505213e-19    0.016520    0.020389    0.020428  0.000000e+00
# 1043     9.486769e-19    0.017992    0.020329    0.020420  1.194175e-02
# 1046     2.800565e-02    0.021077    0.020329    0.020428  1.975144e-02
# 1047     3.212679e-02    0.012454    0.020415    0.020359  3.101499e-02
# 1048     4.693948e-02    0.024155    0.020536    0.020486  3.696493e-02
# 105      4.101908e-02    0.023031    0.020405    0.020447  3.275414e-02
# 1051     3.754493e-02    0.021819    0.020406    0.020436  1.503645e-02
# 1053     5.186293e-02    0.027798    0.020700    0.020632  4.692611e-02
# 1054              NaN         NaN         NaN         NaN           NaN
# 1055              NaN         NaN         NaN         NaN           NaN
# 1056              NaN         NaN         NaN         NaN           NaN
# 1057              NaN         NaN         NaN         NaN           NaN
# 1059              NaN         NaN         NaN         NaN           NaN
#
# [55 rows x 42 columns]

# %%
def load_and_process_ensemble_results(file_path, n_stocks=50):
    """
    앙상블 결과를 로드하고 처리하여 각 날짜별 상위 N개 주식을 선택합니다.
    
    Args:
        file_path (str): 앙상블 결과 파일 경로
        n_stocks (int): 선택할 상위 주식의 수
    
    Returns:
        pd.DataFrame: 각 날짜별 상위 N개 주식의 정보
    """
    # 앙상블 결과 로드
    ensemble_results = pd.read_feather(file_path)
    
    # Long format으로 변환 및 정렬
    ensemble_results_long = (ensemble_results
                             .pivot_table(index='ending_date', columns='StockID', values='up_prob')
                             .reset_index()
                             .melt(id_vars=['ending_date'], var_name='StockID', value_name='up_prob')
                             .sort_values(['ending_date', 'up_prob'], ascending=[True, False]))
    
    # 각 날짜별 상위 N개 주식 선택
    top_stocks = ensemble_results_long.groupby('ending_date').head(n_stocks)
    top_stocks.reset_index(drop=True, inplace=True)
    
    return top_stocks

file_path = './RIPT_WORK_SPACE/ensemble_CNN20_res.feather'
top_stocks = load_and_process_ensemble_results(file_path, n_stocks=50)

print(top_stocks.head())
print(f"\nShape of the dataframe: {top_stocks.shape}")
print(f"Number of unique dates: {top_stocks['ending_date'].nunique()}")
print(f"Number of unique stocks: {top_stocks['StockID'].nunique()}")
# Out:
#   ending_date StockID   up_prob
# 0  2001-01-31     337  0.743836
# 1  2001-01-31    3761  0.732837
# 2  2001-01-31    2211  0.720667
# 3  2001-01-31     351  0.719092
# 4  2001-01-31    5228  0.718951
#
# Shape of the dataframe: (9750, 3)
# Number of unique dates: 195
# Number of unique stocks: 3248

# %%
import numpy as np
import pandas as pd
from scipy.optimize import minimize

# Assuming us_ret and top_stocks are loaded as before

# Function to select top stocks for each rebalance date
def select_top_stocks(top_stocks, rebalance_dates, n):
    selected_stocks = []
    for date in rebalance_dates:
        selected = top_stocks[top_stocks['ending_date'] == date].head(n)['StockID'].values
        selected_stocks.append((date, selected))
    return selected_stocks

# Filter top_stocks to include only data after TRAIN date
top_stocks = top_stocks[top_stocks['ending_date'] >= TRAIN]

# Get unique rebalance dates
rebalance_dates = top_stocks['ending_date'].unique()

# Select top N stocks for each rebalance date
N_TOP_STOCKS = 50  # Number of top stocks to select
selected_stocks_list = select_top_stocks(top_stocks, rebalance_dates, N_TOP_STOCKS)

# Portfolio optimization function
def portfolio_optimization(returns):
    n = returns.shape[1]
    mean_returns = returns.mean()
    cov_matrix = returns.cov()
    constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
    bounds = tuple((0, 1) for _ in range(n))

    def portfolio_variance(weights):
        return weights.T @ cov_matrix @ weights

    initial_weights = np.array(n * [1. / n])

    optimized = minimize(portfolio_variance, initial_weights, method='SLSQP', bounds=bounds, constraints=constraints)

    if optimized.success:
        return optimized.x
    else:
        raise BaseException('Optimization failed')

# Dictionary to store portfolio weights for each period
portfolio_weights = {}

# Iterate over each rebalance period
for i, (rebalance_date, stock_ids) in enumerate(selected_stocks_list):
    # For avoiding look-ahead bias, use data up to the rebalance date
    end_date = rebalance_date
    if i > 0:
        start_date = selected_stocks_list[i - 1][0]  # Previous rebalance date
    else:
        start_date = us_ret.index.min()  # Or a defined start date

    # Extract returns for the optimization period
    period_returns = us_ret.loc[start_date:end_date, stock_ids]

    # Handle missing data
    period_returns = period_returns.dropna(axis=0, how='any')

    if period_returns.shape[0] < 2:
        print(f"Not enough data to optimize for period ending on {end_date}")
        continue

    # Perform portfolio optimization
    try:
        weights = portfolio_optimization(period_returns)
        portfolio_weights[rebalance_date] = pd.Series(weights, index=stock_ids)
        print(f"Optimized portfolio for period starting on {rebalance_date}")
    except Exception as e:
        print(f"Optimization failed for period starting on {rebalance_date}: {e}")

# Display the portfolio weights
portfolio_weights_df = pd.DataFrame(portfolio_weights)
print(portfolio_weights_df)
# Out:
# Optimized portfolio for period starting on 2019-01-31 00:00:00
# Optimized portfolio for period starting on 2019-02-28 00:00:00
# Optimized portfolio for period starting on 2019-04-30 00:00:00
# Optimized portfolio for period starting on 2019-05-31 00:00:00
# Optimized portfolio for period starting on 2019-07-31 00:00:00
# Optimized portfolio for period starting on 2019-09-30 00:00:00
# Optimized portfolio for period starting on 2019-10-31 00:00:00
# Optimized portfolio for period starting on 2019-12-31 00:00:00
# Optimized portfolio for period starting on 2020-01-31 00:00:00
# Optimized portfolio for period starting on 2020-03-31 00:00:00
# Optimized portfolio for period starting on 2020-04-30 00:00:00
# Optimized portfolio for period starting on 2020-06-30 00:00:00
# Optimized portfolio for period starting on 2020-07-31 00:00:00
# Optimized portfolio for period starting on 2020-08-31 00:00:00
# Optimized portfolio for period starting on 2020-09-30 00:00:00
# Optimized portfolio for period starting on 2020-11-30 00:00:00
# Optimized portfolio for period starting on 2020-12-31 00:00:00
# Optimized portfolio for period starting on 2021-03-31 00:00:00
# Optimized portfolio for period starting on 2021-04-30 00:00:00
# Optimized portfolio for period starting on 2021-06-30 00:00:00
# Optimized portfolio for period starting on 2021-08-31 00:00:00
# Optimized portfolio for period starting on 2021-09-30 00:00:00
# Optimized portfolio for period starting on 2021-11-30 00:00:00
# Optimized portfolio for period starting on 2021-12-31 00:00:00
# Optimized portfolio for period starting on 2022-01-31 00:00:00
# Optimized portfolio for period starting on 2022-02-28 00:00:00
# Optimized portfolio for period starting on 2022-03-31 00:00:00
# Optimized portfolio for period starting on 2022-05-31 00:00:00
# Optimized portfolio for period starting on 2022-06-30 00:00:00
# Optimized portfolio for period starting on 2022-08-31 00:00:00
# Optimized portfolio for period starting on 2022-09-30 00:00:00
# Optimized portfolio for period starting on 2022-10-31 00:00:00
# Optimized portfolio for period starting on 2022-11-30 00:00:00
# Optimized portfolio for period starting on 2023-01-31 00:00:00
# Optimized portfolio for period starting on 2023-02-28 00:00:00
# Optimized portfolio for period starting on 2023-03-31 00:00:00
# Optimized portfolio for period starting on 2023-05-31 00:00:00
# Optimized portfolio for period starting on 2023-06-30 00:00:00
# Optimized portfolio for period starting on 2023-07-31 00:00:00
# Optimized portfolio for period starting on 2023-08-31 00:00:00
# Optimized portfolio for period starting on 2023-10-31 00:00:00
# Optimized portfolio for period starting on 2023-11-30 00:00:00
#       2019-01-31  2019-02-28  2019-04-30  2019-05-31  2019-07-31  2019-09-30  \
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1000         NaN         NaN         NaN         NaN         NaN         NaN
# 1001    0.012222         NaN         NaN         NaN         NaN         NaN
# 1002         NaN         NaN         NaN         NaN         NaN         NaN
# 1004         NaN         NaN         NaN         NaN         NaN         NaN
# ...          ...         ...         ...         ...         ...         ...
# 99           NaN         NaN         NaN         NaN         NaN         NaN
# 990          NaN         NaN         NaN         NaN         NaN         NaN
# 991          NaN         NaN         NaN         NaN         NaN         NaN
# 992          NaN         NaN         NaN         NaN         NaN         NaN
# 998          NaN         NaN         NaN         NaN         NaN         NaN
#
#       2019-10-31  2019-12-31  2020-01-31  2020-03-31  ...  2022-11-30  \
# 0            NaN         NaN         NaN         0.0  ...         NaN
# 1000         NaN         NaN         NaN         NaN  ...         NaN
# 1001         NaN         NaN         NaN         NaN  ...         NaN
# 1002         NaN         NaN         NaN         NaN  ...         NaN
# 1004         NaN         NaN         NaN         NaN  ...         NaN
# ...          ...         ...         ...         ...  ...         ...
# 99           NaN         NaN         NaN         NaN  ...         NaN
# 990          NaN         NaN         NaN         NaN  ...         NaN
# 991          NaN         NaN         NaN         NaN  ...         NaN
# 992          NaN         NaN         NaN         NaN  ...         NaN
# 998          NaN         NaN         NaN         NaN  ...         NaN
#
#       2023-01-31  2023-02-28  2023-03-31  2023-05-31  2023-06-30  2023-07-31  \
# 0       0.025606         NaN         NaN         NaN         NaN         NaN
# 1000         NaN         NaN         NaN         NaN         NaN         NaN
# 1001         NaN         NaN         NaN         NaN         NaN         NaN
# 1002         NaN         NaN         NaN         NaN         NaN         NaN
# 1004         NaN         NaN         NaN         NaN         NaN        0.02
# ...          ...         ...         ...         ...         ...         ...
# 99           NaN         NaN         NaN         NaN         NaN         NaN
# 990          NaN         NaN         NaN    0.067181         NaN         NaN
# 991          NaN         NaN         NaN         NaN         NaN         NaN
# 992          NaN         NaN         NaN         NaN         NaN         NaN
# 998          NaN         NaN         NaN         NaN         NaN         NaN
#
#       2023-08-31  2023-10-31  2023-11-30
# 0            NaN         NaN         NaN
# 1000         NaN    0.027202         NaN
# 1001         NaN         NaN         NaN
# 1002         NaN         NaN         NaN
# 1004         NaN         NaN         NaN
# ...          ...         ...         ...
# 99           NaN    0.017910         NaN
# 990          NaN         NaN         NaN
# 991          NaN         NaN         NaN
# 992          NaN         NaN         NaN
# 998          NaN         NaN         NaN
#
# [1621 rows x 42 columns]

# %%
# Initialize a DataFrame to store portfolio returns
portfolio_returns = pd.Series(dtype=float)

# Iterate over each period to calculate portfolio returns
for i, (rebalance_date, weights_series) in enumerate(portfolio_weights.items()):
    # Get the start and end dates for the investment period
    start_date = rebalance_date
    if i < len(portfolio_weights) - 1:
        end_date = list(portfolio_weights.keys())[i + 1]
    else:
        end_date = us_ret.index.max()

    # Get the returns for the period
    period_returns = us_ret.loc[start_date:end_date, weights_series.index]

    # Calculate daily portfolio returns
    daily_portfolio_returns = period_returns.dot(weights_series)

    # Append to the portfolio_returns series
    portfolio_returns = portfolio_returns._append(daily_portfolio_returns)

# Calculate cumulative returns
cumulative_returns = (1 + portfolio_returns).cumprod()

# Plot cumulative returns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
cumulative_returns.plot()
plt.title('Portfolio Cumulative Returns')
plt.xlabel('Date')
plt.ylabel('Cumulative Returns')
plt.show()
# Out:
# /tmp/ipykernel_90281/2364858782.py:20: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   portfolio_returns = portfolio_returns._append(daily_portfolio_returns)

# %%
def load_ensemble_results(folder_path):
    """폴더 내의 모든 앙상블 결과 파일을 로드하고 하나의 데이터프레임으로 병합합니다."""
    all_data = []
    for file in os.listdir(folder_path):
        if file.endswith('.csv'):
            file_path = os.path.join(folder_path, file)
            df = pd.read_csv(file_path)
            df['Date'] = pd.to_datetime(df['ending_date']) - pd.DateOffset(months=1)
            df['StockID'] = df['StockID'].astype(str)
            df.drop('ending_date', axis=1, inplace=True)
            all_data.append(df)
    
    combined_df = pd.concat(all_data)
    combined_df.sort_values('Date', inplace=True)
    combined_df.reset_index(drop=True, inplace=True)
    return combined_df

def select_top_stocks(df, date, top_n):
    """특정 날짜에 대해 상승 확률이 높은 상위 N개 주식을 선택합니다."""
    date_df = df.loc[date].sort_values('up_prob', ascending=False)
    return date_df.head(top_n)

def select_bottom_stocks(df, date, bottom_n):
    """특정 날짜에 대해 상승 확률이 낮은 하위 N개 주식을 선택합니다."""
    date_df = df.loc[date].sort_values('up_prob', ascending=True)
    return date_df.head(bottom_n)

# 메인 실행 코드
folder_path = 'RIPT_WORK_SPACE/new_model_res/CNN20/20D20P/ensem_res'
ensemble_results = load_ensemble_results(folder_path)
ensemble_results
# Out:
#         Unnamed: 0 StockID   up_prob   ret_val  MarketCap       Date
# 0                0       0  0.569300 -0.296981        0.0 2000-12-31
# 1               66    2368  0.490216  0.023412        0.0 2000-12-31
# 2              119     558  0.591819 -0.004300        0.0 2000-12-31
# 3               75     237  0.517707  0.119050        0.0 2000-12-31
# 4               84    2375  0.585768 -0.031380        0.0 2000-12-31
# ...            ...     ...       ...       ...        ...        ...
# 619998          51      48  0.590559  0.012950        0.0 2023-10-30
# 619999          34    3149  0.647246  0.216225        0.0 2023-10-30
# 620000          42    4797  0.567163  0.082465        0.0 2023-10-30
# 620001           3    1937  0.610773  0.057797        0.0 2023-10-30
# 620002          90    5340  0.529650 -0.484765        0.0 2023-10-30
#
# [620003 rows x 6 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def backtest(ensemble_results, n_stocks, opt_type='equal_weight', select_type='top'):
    """
    주어진 앙상블 결과를 사용하여 백테스트를 수행합니다.
    
    Args:
    ensemble_results (pd.DataFrame): 앙상블 결과 데이터프레임
    n_stocks (int): 선택할 주식 수
    opt_type (str): 최적화 유형 ('equal_weight', 'min_variance', 'max_sharpe')
    select_type (str): 주식 선택 유형 ('top' 또는 'bottom')
    
    Returns:
    pd.Series: 포트폴리오 수익률
    dict: 각 기간의 포트폴리오 가중치
    """
    portfolio_returns = []
    portfolio_weights = {}
    
    # Unnamed: 0 열 제거
    ensemble_results = ensemble_results.drop('Unnamed: 0', axis=1)
    
    # 고유한 날짜 목록 가져오기
    dates = ensemble_results['Date'].unique()
    dates.sort()
    
    for i, current_date in enumerate(dates[:-1]):
        next_date = dates[i+1]
        
        # 현재 날짜의 데이터 선택
        current_data = ensemble_results[ensemble_results['Date'] == current_date]
        
        # 상위 또는 하위 N개 주식 선택
        if select_type == 'top':
            selected_stocks = current_data.nlargest(n_stocks, 'up_prob')
        else:
            selected_stocks = current_data.nsmallest(n_stocks, 'up_prob')
        
        # 가중치 계산
        if opt_type == 'equal_weight':
            weights = np.ones(n_stocks) / n_stocks
        elif opt_type == 'min_variance':
            # 여기에 최소 분산 포트폴리오 최적화 로직 구현
            pass
        elif opt_type == 'max_sharpe':
            # 여기에 최대 샤프 비율 포트폴리오 최적화 로직 구현
            pass
        
        # 다음 날짜의 수익률 데이터 가져오기
        next_returns = ensemble_results[ensemble_results['Date'] == next_date]
        next_returns = next_returns.set_index('StockID')['ret_val']
        next_returns = next_returns.loc[selected_stocks['StockID']]
        
        # 포트폴리오 수익률 계산
        period_return = np.dot(weights, next_returns)
        portfolio_returns.append(period_return)
        
        # 가중치 저장
        portfolio_weights[current_date] = pd.Series(weights, index=selected_stocks['StockID'])
    
    return pd.Series(portfolio_returns, index=dates[1:]), portfolio_weights

# 백테스트 실행 예시
n_stocks = 50
opt_type = 'equal_weight'
select_type = 'top'

portfolio_returns, portfolio_weights = backtest(ensemble_results, n_stocks, opt_type, select_type)

# 결과 출력
print("Portfolio Returns:")
print(portfolio_returns)

print("\nPortfolio Weights for the first period:")
print(next(iter(portfolio_weights.values())))

# 누적 수익률 계산 및 시각화
cumulative_returns = (1 + portfolio_returns).cumprod()

plt.figure(figsize=(12, 6))
cumulative_returns.plot()
plt.title('Cumulative Portfolio Returns')
plt.xlabel('Date')
plt.ylabel('Cumulative Returns')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 70
#      67 opt_type = 'equal_weight'
#      68 select_type = 'top'
# ---> 70 portfolio_returns, portfolio_weights = backtest(ensemble_results, n_stocks, opt_type, select_type)
#      72 # 결과 출력
#      73 print("Portfolio Returns:")
#
# Cell In[61], line 27, in backtest(ensemble_results, n_stocks, opt_type, select_type)
#      25 # 고유한 날짜 목록 가져오기
#      26 dates = ensemble_results['Date'].unique()
# ---> 27 dates.sort()
#      29 for i, current_date in enumerate(dates[:-1]):
#      30     next_date = dates[i+1]
#
# AttributeError: 'DatetimeArray' object has no attribute 'sort'

# %%
# 2018년 이후의 데이터만 선택
start_date = pd.Timestamp('2019-01-01')
ensemble_results = ensemble_results[ensemble_results.index.get_level_values('Date') >= start_date]

strategies = {
    'Top 50 (Equal Weight)': (50, 'equal_weight', 'top'),
    'Top 100 (Equal Weight)': (100, 'equal_weight', 'top'),
    'Top N/5 (Equal Weight)': (len(ensemble_results.index.get_level_values('StockID').unique()) // 5, 'equal_weight', 'top'),
    'Top N/2 (Equal Weight)': (len(ensemble_results.index.get_level_values('StockID').unique()) // 2, 'equal_weight', 'top'),
    'Top 50 (Min Variance)': (50, 'min_variance', 'top'),
    'Top 50 (Max Sharpe)': (50, 'max_sharpe', 'top'),

    'Bottom 50 (Equal Weight)': (50, 'equal_weight', 'bottom'),
    'Bottom 100 (Equal Weight)': (100, 'equal_weight', 'bottom'),
    'Bottom N/5 (Equal Weight)': (len(ensemble_results.index.get_level_values('StockID').unique()) // 5, 'equal_weight', 'bottom'),
    'Bottom N/2 (Equal Weight)': (len(ensemble_results.index.get_level_values('StockID').unique()) // 2, 'equal_weight', 'bottom'),
}

results = {}
for name, (n, opt_type, select_type) in strategies.items():
    print(f"Running backtest for {name}...")
    portfolio_returns, portfolio_weights = backtest(ensemble_results, n, opt_type, select_type)
    cumulative_returns = (1 + portfolio_returns).cumprod()
    results[name] = cumulative_returns

# %%
# 2018년 이후의 데이터만 선택
start_date = pd.Timestamp('2019-01-01')
ensemble_results = ensemble_results[ensemble_results['Date'] >= start_date]

strategies = {
    'Top 50 (Equal Weight)': (50, 'equal_weight', 'top'),
    'Top 100 (Equal Weight)': (100, 'equal_weight', 'top'),
    'Top N/5 (Equal Weight)': (len(ensemble_results.index.get_level_values('StockID').unique()) // 5, 'equal_weight', 'top'),
    'Top N/2 (Equal Weight)': (len(ensemble_results.index.get_level_values('StockID').unique()) // 2, 'equal_weight', 'top'),
    'Top 50 (Min Variance)': (50, 'min_variance', 'top'),
    'Top 50 (Max Sharpe)': (50, 'max_sharpe', 'top'),

    'Bottom 50 (Equal Weight)': (50, 'equal_weight', 'bottom'),
    'Bottom 100 (Equal Weight)': (100, 'equal_weight', 'bottom'),
    'Bottom N/5 (Equal Weight)': (len(ensemble_results.index.get_level_values('StockID').unique()) // 5, 'equal_weight', 'bottom'),
    'Bottom N/2 (Equal Weight)': (len(ensemble_results.index.get_level_values('StockID').unique()) // 2, 'equal_weight', 'bottom'),
}

results = {}
for name, (n, opt_type, select_type) in strategies.items():
    print(f"Running backtest for {name}...")
    portfolio_returns, portfolio_weights = backtest(ensemble_results, n, opt_type, select_type)
    cumulative_returns = (1 + portfolio_returns).cumprod()
    results[name] = cumulative_returns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 8
#       2 start_date = pd.Timestamp('2019-01-01')
#       3 ensemble_results = ensemble_results[ensemble_results['Date'] >= start_date]
#       5 strategies = {
#       6     'Top 50 (Equal Weight)': (50, 'equal_weight', 'top'),
#       7     'Top 100 (Equal Weight)': (100, 'equal_weight', 'top'),
# ----> 8     'Top N/5 (Equal Weight)': (len(ensemble_results.index.get_level_values('StockID').unique()) // 5, 'equal_weight', 'top'),
#       9     'Top N/2 (Equal Weight)': (len(ensemble_results.index.get_level_values('StockID').unique()) // 2, 'equal_weight', 'top'),
#      10     'Top 50 (Min Variance)': (50, 'min_variance', 'top'),
#      11     'Top 50 (Max Sharpe)': (50, 'max_sharpe', 'top'),
#      12
#      13     'Bottom 50 (Equal Weight)': (50, 'equal_weight', 'bottom'),
#      14     'Bottom 100 (Equal Weight)': (100, 'equal_weight', 'bottom'),
#      15     'Bottom N/5 (Equal Weight)': (len(ensemble_results.index.get_level_values('StockID').unique()) // 5, 'equal_weight', 'bottom'),
#      16     'Bottom N/2 (Equal Weight)': (len(ensemble_results.index.get_level_values('StockID').unique()) // 2, 'equal_weight', 'bottom'),
#      17 }
#      19 results = {}
#      20 for name, (n, opt_type, select_type) in strategies.items():
#
# File ~/anaconda3/envs/imagedpo2/lib/python3.11/site-packages/pandas/core/indexes/base.py:2102, in Index._get_level_values(self, level)
#    2066 def _get_level_values(self, level) -> Index:
#    2067     """
#    2068     Return an Index of values for requested level.
#    2069
#    (...)
#    2100     Index(['a', 'b', 'c'], dtype='object')
#    2101     """
# -> 2102     self._validate_index_level(level)
#    2103     return self
#
# File ~/anaconda3/envs/imagedpo2/lib/python3.11/site-packages/pandas/core/indexes/base.py:2012, in Index._validate_index_level(self, level)
#    2008         raise IndexError(
#    2009             f"Too many levels: Index has only 1 level, not {level + 1}"
#    2010         )
#    2011 elif level != self.name:
# -> 2012     raise KeyError(
#    2013         f"Requested level ({level}) does not match index name ({self.name})"
#    2014     )
#
# KeyError: 'Requested level (StockID) does not match index name (None)'

# %%
# 누적 수익률 비교 그래프
plt.figure(figsize=(15, 10))

colors = plt.cm.Reds(np.linspace(0.4, 0.8, 6))  # Top 전략을 위한 붉은 계열 색상
colors = np.vstack((colors, plt.cm.Blues(np.linspace(0.4, 0.8, 6))))  # Bottom 전략을 위한 파란 계열 색상 추가

for (name, cumulative_returns), color in zip(results.items(), colors):
    if 'Top' in name:
        plt.plot(cumulative_returns.index, cumulative_returns.values, label=name, color=color, linewidth=2, alpha=0.7)
    else:
        plt.plot(cumulative_returns.index, cumulative_returns.values, label=name, color=color, linewidth=2, alpha=0.7)

plt.title('Portfolio Cumulative Returns Comparison (2018-2023)', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Cumulative Returns', fontsize=12)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=10)
plt.tight_layout()
plt.grid(True, alpha=0.3)
plt.show()

# 성과 지표 계산 및 출력
print("\nPerformance Metrics (2018-2023):")
print("-" * 80)
print(f"{'Strategy':<30} {'Total Return':>15} {'Ann. Return':>15} {'Ann. Volatility':>15} {'Sharpe Ratio':>15}")
print("-" * 80)

for name, cumulative_returns in results.items():
    portfolio_returns = cumulative_returns.pct_change().dropna()
    total_return = cumulative_returns.iloc[-1] - 1
    years = (cumulative_returns.index[-1] - cumulative_returns.index[0]).days / 365.25
    annualized_return = (1 + total_return) ** (1 / years) - 1
    annualized_volatility = portfolio_returns.std() * np.sqrt(252)
    sharpe_ratio = annualized_return / annualized_volatility
    
    print(f"{name:<30} {total_return:15.2%} {annualized_return:15.2%} {annualized_volatility:15.2%} {sharpe_ratio:15.2f}")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Performance Metrics (2018-2023):
# --------------------------------------------------------------------------------
# Strategy                          Total Return     Ann. Return Ann. Volatility    Sharpe Ratio
# --------------------------------------------------------------------------------

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from skfolio import RiskMeasure, RatioMeasure
from skfolio.optimization import MeanRisk, EqualWeighted, InverseVolatility, Random
from skfolio.preprocessing import prices_to_returns
from skfolio.moments import EmpiricalCovariance, EmpiricalMu
from skfolio.prior import EmpiricalPrior

# 데이터 로드 및 전처리
folder_path = 'RIPT_WORK_SPACE/new_model_res/CNN20/20D20P/ensem_res/'
ensemble_results = load_ensemble_results(folder_path)

# 2018년 이후의 데이터만 선택
start_date = pd.Timestamp('2018-01-01')
ensemble_results = ensemble_results[ensemble_results.index.get_level_values('Date') >= start_date]

# 수익률 데이터 준비
returns = ensemble_results['ret_val'].unstack()

# 전략 정의
strategies = {
    'Equal Weighted': EqualWeighted(),
    'Inverse Volatility': InverseVolatility(),
    'Random Portfolio': Random(),
    'Minimum Variance': MeanRisk(
        risk_measure=RiskMeasure.VARIANCE,
        prior_estimator=EmpiricalPrior(
            mu_estimator=EmpiricalMu(),
            covariance_estimator=EmpiricalCovariance()
        )
    ),
    'Maximum Sharpe Ratio': MeanRisk(
        objective_function="sharpe_ratio",
        risk_measure=RiskMeasure.VARIANCE,
        prior_estimator=EmpiricalPrior(
            mu_estimator=EmpiricalMu(),
            covariance_estimator=EmpiricalCovariance()
        )
    )
}

# 백테스트 함수
def backtest(returns, model):
    portfolio_returns = []
    for i in range(len(returns) - 1):
        train_returns = returns.iloc[:i+1]
        test_returns = returns.iloc[i+1]
        
        model.fit(train_returns)
        weights = model.weights_
        
        portfolio_return = np.sum(test_returns * weights)
        portfolio_returns.append(portfolio_return)
    
    return pd.Series(portfolio_returns, index=returns.index[1:])

# 백테스트 실행
results = {}
for name, model in strategies.items():
    print(f"Running backtest for {name}...")
    portfolio_returns = backtest(returns, model)
    results[name] = (1 + portfolio_returns).cumprod()

# 결과 시각화
plt.figure(figsize=(15, 10))
colors = plt.cm.rainbow(np.linspace(0, 1, len(results)))

for (name, cumulative_returns), color in zip(results.items(), colors):
    plt.plot(cumulative_returns.index, cumulative_returns.values, label=name, color=color, linewidth=2, alpha=0.7)

plt.title('Portfolio Cumulative Returns Comparison (2018-2023)', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Cumulative Returns', fontsize=12)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=10)
plt.tight_layout()
plt.grid(True, alpha=0.3)
plt.show()

# 성과 지표 계산 및 출력
print("\nPerformance Metrics (2018-2023):")
print("-" * 80)
print(f"{'Strategy':<20} {'Total Return':>15} {'Ann. Return':>15} {'Ann. Volatility':>15} {'Sharpe Ratio':>15}")
print("-" * 80)

for name, cumulative_returns in results.items():
    portfolio_returns = cumulative_returns.pct_change().dropna()
    total_return = cumulative_returns.iloc[-1] - 1
    years = (cumulative_returns.index[-1] - cumulative_returns.index[0]).days / 365.25
    annualized_return = (1 + total_return) ** (1 / years) - 1
    annualized_volatility = portfolio_returns.std() * np.sqrt(252)
    sharpe_ratio = annualized_return / annualized_volatility
    
    print(f"{name:<20} {total_return:15.2%} {annualized_return:15.2%} {annualized_volatility:15.2%} {sharpe_ratio:15.2f}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 16
#      14 # 2018년 이후의 데이터만 선택
#      15 start_date = pd.Timestamp('2018-01-01')
# ---> 16 ensemble_results = ensemble_results[ensemble_results.index.get_level_values('Date') >= start_date]
#      18 # 수익률 데이터 준비
#      19 returns = ensemble_results['ret_val'].unstack()
#
# File ~/anaconda3/envs/imagedpo2/lib/python3.11/site-packages/pandas/core/indexes/base.py:2102, in Index._get_level_values(self, level)
#    2066 def _get_level_values(self, level) -> Index:
#    2067     """
#    2068     Return an Index of values for requested level.
#    2069
#    (...)
#    2100     Index(['a', 'b', 'c'], dtype='object')
#    2101     """
# -> 2102     self._validate_index_level(level)
#    2103     return self
#
# File ~/anaconda3/envs/imagedpo2/lib/python3.11/site-packages/pandas/core/indexes/base.py:2012, in Index._validate_index_level(self, level)
#    2008         raise IndexError(
#    2009             f"Too many levels: Index has only 1 level, not {level + 1}"
#    2010         )
#    2011 elif level != self.name:
# -> 2012     raise KeyError(
#    2013         f"Requested level ({level}) does not match index name ({self.name})"
#    2014     )
#
# KeyError: 'Requested level (Date) does not match index name (None)'

# %%
returns
# Out:
# StockID            0         1      1001      1002      1012      1014  \
# Date
# 2018-01-31 -0.066704 -0.134569 -0.101545 -0.210570 -0.152447 -0.039041
# 2018-02-28 -0.043135  0.133765 -0.060897  0.093428 -0.065723 -0.096068
# 2018-04-30 -0.055944 -0.062075  0.137643 -0.003295  0.029046 -0.023089
# 2018-05-31  0.066061 -0.099906 -0.010873 -0.055852 -0.151208  0.078757
# 2018-07-31  0.023958  0.031864 -0.023927 -0.257116  0.001623 -0.008393
# 2018-08-31 -0.040947 -0.215054 -0.270062 -0.219620 -0.313385 -0.080455
# 2018-10-31  0.117195 -0.091767 -0.064996  0.130472  0.277263 -0.011475
# 2018-11-30 -0.068737 -0.163200 -0.163404 -0.207028 -0.158521 -0.197393
# 2018-12-31  0.128357  0.116581  0.314919  0.285794  0.321637  0.239424
# 2019-01-31  0.044216 -0.006244  0.089748 -0.066350 -0.031543 -0.008064
# 2019-02-28 -0.008550 -0.096762 -0.032368  0.009977  0.096884  0.105835
# 2019-04-30 -0.147274 -0.204902 -0.169138  0.100616 -0.315752 -0.121201
# 2019-05-31  0.037076  0.061390  0.106197  0.359085  0.291602  0.143550
# 2019-07-31  0.101704 -0.108180 -0.097431 -0.188044  0.269684 -0.027984
# 2019-09-30 -0.012022  0.040062  0.136049  0.102715  0.007426  0.041122
# 2019-10-31  0.126726  0.035337  0.100435 -0.093942 -0.057855  0.115034
# 2019-12-31 -0.032095 -0.350279 -0.003876  0.011514 -0.028978 -0.067851
# 2020-01-31 -0.130965 -0.558365 -0.516454 -0.160494 -0.531050 -0.434192
# 2020-03-31  0.070195  0.327691  0.155770  0.107403  0.094438  0.153565
# 2020-04-30  0.151884  0.377013  0.253770  0.454355  0.430215  0.052210
# 2020-06-30  0.089059  0.157238  0.131635 -0.193853  0.112049 -0.020518
# 2020-07-31  0.042809  0.123322  0.132515  0.093956  0.093792  0.022405
# 2020-08-31  0.005345 -0.204670  0.147608 -0.096818  0.079351 -0.157372
# 2020-09-30  0.161164  0.713154  0.252075  0.023727  0.120841  0.277622
# 2020-11-30  0.012916  0.157555  0.113160  0.075455  0.021843  0.119756
# 2020-12-31  0.074181  0.408791  0.377038  0.348972  0.380578  0.179507
# 2021-03-31  0.049192  0.128045  0.123283 -0.155975  0.064966 -0.020702
# 2021-04-30  0.106751  0.003105 -0.069609  0.278515 -0.134813 -0.007968
# 2021-06-30  0.188051  0.203143 -0.002839  0.363180 -0.030088  0.017511
# 2021-08-31 -0.100000  0.104415  0.031263 -0.095706 -0.076630 -0.024683
# 2021-09-30 -0.042208 -0.053770 -0.069009 -0.201389  0.136645 -0.092763
